# %%
import pandas as pd
import numpy as np
import GetOldTweets3 as got
from datetime import datetime, timedelta

# %%
ls
# Out:
# 2012topic1.png            SenateList.csv            testing2012.csv
# 2012topic2.png            SenateList1.csv           testing2016.csv
# HillaryElection.csv       TestingData.ipynb         train2012.csv
# IMMALERE.png              TrainingData.ipynb        train2016.csv
# ObamaElection.csv         TrumpElection.csv         training2012.csv
# RomneyElection.csv        Updated_Senate_List.csv   training2016.csv
# Senate List.xlsx          Updated_Senate_List.xlsx

# %%
data = pd.read_csv('Updated_Senate_List.csv', sep = ',')
data.head(5)
# Out:
#         2012 Senate Party State  Twitter Account  #Tweets        2016 Senate  \
# 0        Al Franken     D    MN        AlFranken      NaN         Al Franken
# 1     Amy Klobuchar     D    MN  SenAmyKlobuchar      NaN      Amy Klobuchar
# 2     Barbara Boxer     D    CA     BarbaraBoxer      NaN  Angus S. King Jr.
# 3  Barbara Mikulski     D    MD      SenatorBarb      NaN      Barbara Boxer
# 4        Ben Nelson     D    NE             NONE      NaN   Barbara Mikulski
#
#   Party.1 State.1 Twitter Account.1  #Tweets.1     Current Senate Party.2  \
# 0       D      MN         AlFranken        NaN      Amy Klobuchar       D
# 1       D      MN   SenAmyKlobuchar        NaN  Angus S. King Jr.       I
# 2       I      ME      SenAngusKing        NaN          Ben Sasse       R
# 3       D      CA      BarbaraBoxer        NaN    Benjamin Cardin       D
# 4       D      MD       SenatorBarb        NaN    Bernard Sanders       D
#
#   State.2 Twitter Account.2
# 0      MN   SenAmyKlobuchar
# ...

# %%
data[['Current Senate', 'Party.2', 'State.2', 'Twitter Account.2']]
# Out:
#         Current Senate Party.2 State.2 Twitter Account.2
# 0        Amy Klobuchar       D      MN   SenAmyKlobuchar
# 1    Angus S. King Jr.       I      ME      SenAngusKing
# 2            Ben Sasse       R      NE          SenSasse
# 3      Benjamin Cardin       D      MD     SenatorCardin
# 4      Bernard Sanders       D      VT        SenSanders
# ..                 ...     ...     ...               ...
# 105        Andrew Yang       D     NaN        AndrewYang
# 106     Pete Buttigieg       D     NaN     PeteButtigieg
# 107  Michael Bloomberg       D     NaN     MikeBloomberg
# 108         Tom Steyer       D     NaN         TomSteyer
# 109      Deval Patrick       D     NaN       DevalPatric
#
# [110 rows x 4 columns]

# %% [markdown]
# # 2020 Election Year

# %%
# 2020 Election year
account2020 = list(data['Twitter Account.2'].values)
tweets2020 = pd.DataFrame(columns = ['Datetime', 'Text','TweetID','username','geo'])

for account in account2020:
    print(account)
    if account == 'NONE':
        print('\t Skip scraping because of invalid twitter account input')
        continue
    else:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account)\
                                           .setSince('2020-01-01')\
                                           .setUntil('2020-05-29')\
                                           .setMaxTweets(5000)
        tweets = got.manager.TweetManager.getTweets(tweetCriteria)
        tweets_detail = [[tweet.date, tweet.text,tweet.id,tweet.username,tweet.geo ] for tweet in tweets]
        tweets2020 = tweets2020.append(pd.DataFrame(tweets_detail, 
                                                    columns = ['Datetime', 'Text','TweetID','username','geo']), 
                                       ignore_index = True)
        print('\t Done scraping')
# Out:
# SenAmyKlobuchar
# 	 Done scraping
# SenAngusKing
# 	 Done scraping
# SenSasse
# 	 Done scraping
# SenatorCardin
# 	 Done scraping
# SenSanders
# 	 Done scraping
# SenBillCassidy
# 	 Done scraping
# SenBrianSchatz
# 	 Done scraping
# SenCortezMasto
# 	 Done scraping
# SenSchumer
# 	 Done scraping
# ChrisVanHollen
# 	 Done scraping
# ChrisCoons
# 	 Done scraping
# SenMurphyOffice
# 	 Done scraping
# ChuckGrassley
# 	 Done scraping
# SenHydeSmith
# 	 Done scraping
# CoryBooker
# 	 Done scraping
# SenCoryGardner
# 	 Done scraping
# SenDanSullivan
# 	 Done scraping
# sendavidperdue
# 	 Done scraping
# SenatorFischer
# 	 Done scraping
# SenStabenow
# 	 Done scraping
# SenFeinstein
# 	 Done scraping
# SenDougJones
# 	 Done scraping
# SenMarkey
# 	 Done scraping
# SenWarren
# 	 Done scraping
# SenGaryPeters
# 	 Done scraping
# SenJackReed
# 	 Done scraping
# SenJackyRosen
# 	 Done scraping
# SenatorRisch
# 	 Done scraping
# JimInhofe
# 	 Done scraping
# SenatorLankford
# 	 Done scraping
# ...

# %%
print(len(tweets2020))
tweets2020.sample(5)
# Out:
# 13113
#                         Datetime  \
# 3449   2020-02-10 16:14:00+00:00
# 6648   2020-01-01 20:23:16+00:00
# 12076  2020-02-25 23:31:01+00:00
# 1791   2020-01-30 14:24:37+00:00
# 11024  2020-04-16 22:39:41+00:00
#
#                                                     Text              TweetID  \
# 3449   Not only is retaliation against LTC Vindman, t...  1226902142583222272
# 6648   I introduced my VA Readiness Initiative earlie...  1212469359018463234
# 12076  Proud to vote in favor of the pro-life bills t...  1232447941907906560
# 1791   Great News! @USDA just announced a $15.5M inve...  1222888350702624768
# 11024  .@SenatorLankford &amp; I are pleased to welco...  1250916801627774977
#
#              username geo
# 3449       SenSchumer
# 6648   SenCoryGardner
# 12076       JimInhofe
# 1791   SenBillCassidy
# 11024   SenJackyRosen

# %%
# Finish scraping up to SenJeffMerkley, starting the iteration again at account2020[32:]

# %%
for account in account2020[32:]:
    print(account)
    if account == 'NONE':
        print('\t Skip scraping because of invalid twitter account input')
        continue
    else:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account)\
                                           .setSince('2020-01-01')\
                                           .setUntil('2020-05-29')\
                                           .setMaxTweets(5000)
        tweets = got.manager.TweetManager.getTweets(tweetCriteria)
        tweets_detail = [[tweet.date, tweet.text,tweet.id,tweet.username,tweet.geo ] for tweet in tweets]
        tweets2020 = tweets2020.append(pd.DataFrame(tweets_detail, 
                                                    columns = ['Datetime', 'Text','TweetID','username','geo']), 
                                       ignore_index = True)
        print('\t Done scraping')
# Out:
# JerryMoran
# 	 Done scraping
# Sen_JoeManchin
# 	 Done scraping
# SenJohnBarrasso
# 	 Done scraping
# JohnBoozman
# 	 Done scraping
# JohnCornyn
# 	 Done scraping
# SenHawleyPress
# 	 Done scraping
# SenJohnHoeven
# 	 Done scraping
# SenJohnKennedy
# 	 Done scraping
# SenJohnThune
# 	 Done scraping
# SenatorTester
# 	 Done scraping
# SenJoniErnst
# 	 Done scraping
# SenKamalaHarris
# 	 Done scraping
# SenatorLoeffler
# 	 Done scraping
# SenKevinCramer
# 	 Done scraping
# gillibrandny
# 	 Done scraping
# SenatorSinema
# 	 Done scraping
# SenAlexander
# 	 Done scraping
# LindseyGrahamSC
# 	 Done scraping
# lisamurkowski
# 	 Done scraping
# SenRubioPress
# 	 Done scraping
# SenatorHassan
# 	 Done scraping
# SenatorCantwell
# 	 Done scraping
# MarkWarner
# 	 Done scraping
# MarshaBlackburn
# 	 Done scraping
# SenMcSallyAZ
# 	 Done scraping
# MartinHeinrich
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# ...

# %%
print(len(tweets2020))
tweets2020.sample(5)
# Out:
# 26709
#                         Datetime  \
# 394    2020-05-28 16:49:24+00:00
# 6899   2020-02-17 01:00:41+00:00
# 8741   2020-04-13 19:32:07+00:00
# 16755  2020-05-26 16:39:06+00:00
# 7135   2020-02-21 19:39:55+00:00
#
#                                                     Text              TweetID  \
# 394    HAPPENING SOON: Looking forward to this discus...  1266048940136435713
# 6899   In so doing, she helped pass Alaska’s Anti-Dis...  1229209016410279936
# 8741   Sanctions programs are not successful if they ...  1249782438848614400
# 16755  You can’t trust the Chinese Communist Party—ev...  1265321572736421889
# 7135   With over 7 million job openings in America to...  1230940230347362304
#
#              username geo
# 394     SenatorCardin
# 6899   SenDanSullivan
# 8741        SenMarkey
# 16755  SenJohnKennedy
# 7135   sendavidperdue

# %%
# Finish scraping up to SenMcSallyAZ, starting the iteration again at account2020[57:]

# %%
for account in account2020[57:]:
    print(account)
    if account == 'NONE':
        print('\t Skip scraping because of invalid twitter account input')
        continue
    else:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account)\
                                           .setSince('2020-01-01')\
                                           .setUntil('2020-05-29')\
                                           .setMaxTweets(5000)
        tweets = got.manager.TweetManager.getTweets(tweetCriteria)
        tweets_detail = [[tweet.date, tweet.text,tweet.id,tweet.username,tweet.geo ] for tweet in tweets]
        tweets2020 = tweets2020.append(pd.DataFrame(tweets_detail, 
                                                    columns = ['Datetime', 'Text','TweetID','username','geo']), 
                                       ignore_index = True)
        print('\t Done scraping')
# Out:
# MartinHeinrich
# 	 Done scraping
# maziehirono
# 	 Done scraping
# SenatorEnzi
# 	 Done scraping
# SenatorBennet
# 	 Done scraping
# SenatorBraun
# 	 Done scraping
# MikeCrapo
# 	 Done scraping
# SenMikeLee
# 	 Done scraping
# SenatorRounds
# 	 Done scraping
# SenateMajLdr
# 	 Done scraping
# SenatorRomney
# 	 Done scraping
# SenPatRoberts
# 	 Done scraping
# SenToomey
# 	 Done scraping
# SenatorLeahy
# 	 Done scraping
# PattyMurray
# 	 Done scraping
# RandPaul
# 	 Done scraping
# SenBlumenthal
# 	 Done scraping
# SenatorBurr
# 	 Done scraping
# SenShelby
# 	 Done scraping
# SenatorDurbin
# 	 Done scraping
# SenRickScott
# 	 Done scraping
# senrobportman
# 	 Done scraping
# SenatorMenedez
# 	 Done scraping
# SenBobCasey
# 	 Done scraping
# SenatorWicker
# 	 Done scraping
# SenRonJohnson
# 	 Done scraping
# RonWyden
# 	 Done scraping
# RoyBlunt
# 	 Done scraping
# SenWhitehouse
# 	 Done scraping
# SenCapito
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# ...

# %%
print(len(tweets2020))
tweets2020.sample(5)
# Out:
# 39654
#                         Datetime  \
# 25179  2020-05-22 11:55:02+00:00
# 9598   2020-04-03 17:31:11+00:00
# 22442  2020-04-02 22:43:30+00:00
# 15053  2020-05-02 22:25:40+00:00
# 19611  2020-04-20 20:08:01+00:00
#
#                                                     Text              TweetID  \
# 25179  Get wisdom, get understanding; do not forget m...  1263800535943131136
# 9598   Testing should be free & accessible for all. T...  1246128122975719424
# 22442  These are stressful, uncertain times, but as w...  1245844335385391104
# 15053  East Texas housing authorities to receive $1.7...  1256711483339223040
# 19611  Right now, the highest number of Saudi oil tan...  1252328188371521538
#
#               username geo
# 25179  MarshaBlackburn
# 9598         SenWarren
# 22442    lisamurkowski
# 15053       JohnCornyn
# 19611   SenKevinCramer

# %%
# Finish scraping up to SenWhitehouse, starting the iteration again at account2020[85:]

# %%
for account in account2020[85:]:
    print(account)
    if account == 'NONE':
        print('\t Skip scraping because of invalid twitter account input')
        continue
    else:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account)\
                                           .setSince('2020-01-01')\
                                           .setUntil('2020-05-29')\
                                           .setMaxTweets(5000)
        tweets = got.manager.TweetManager.getTweets(tweetCriteria)
        tweets_detail = [[tweet.date, tweet.text,tweet.id,tweet.username,tweet.geo ] for tweet in tweets]
        tweets2020 = tweets2020.append(pd.DataFrame(tweets_detail, 
                                                    columns = ['Datetime', 'Text','TweetID','username','geo']), 
                                       ignore_index = True)
        print('\t Done scraping')
# Out:
# SenCapito
# 	 Done scraping
# SenSherrodBrown
# 	 Done scraping
# SteveDaines
# 	 Done scraping
# SenatorCollins
# 	 Done scraping
# SenatorBaldwin
# 	 Done scraping
# SenDuckworth
# 	 Done scraping
# SenTedCruz
# 	 Done scraping
# SenThomTillis
# 	 Done scraping
# SenatorCarper
# 	 Done scraping
# NONE
# 	 Skip scraping because of invalid twitter account input
# SenatorTimScott
# 	 Done scraping
# SenTinaSmith
# 	 Done scraping
# SenToddYoung
# 	 Done scraping
# SenTomCotton
# 	 Done scraping
# SenatorTomUdall
# 	 Done scraping
# nan
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-ee3f4f80e926> in <module>
#       9                                            .setUntil('2020-05-29')\
#      10                                            .setMaxTweets(5000)
# ---> 11         tweets = got.manager.TweetManager.getTweets(tweetCriteria)
# ...

# %%
print(len(tweets2020))
tweets2020.sample(5)
# Out:
# 47281
#                         Datetime  \
# 20924  2020-02-29 17:01:30+00:00
# 14936  2020-05-14 10:44:50+00:00
# 30608  2020-04-29 00:05:00+00:00
# 29215  2020-05-15 18:21:56+00:00
# 9665   2020-03-26 13:28:01+00:00
#
#                                                     Text              TweetID  \
# 20924  .@NAU's Teachers Academy is strengthening Ariz...  1233799465250758656
# 14936  @WSJ A stunning 39 separate officials snooped ...  1260883766043697152
# 30608  It's simple: vaccines are safe, effective, & l...  1255286927516975104
# 29215  80,000 Americans have died. More than 20 milli...  1261361186148319232
# 9665   Restarting our economy will require one thing ...  1243167825138798594
#
#             username geo
# 20924  SenatorSinema
# 14936     JohnCornyn
# 30608    PattyMurray
# 29215   senatemajldr
# 9665       SenWarren

# %%
# Finish scraping up to SenatorTomUdall, starting the iteration again at account2020[102:]

# %%
for account in account2020[102:]:
    print(account)
    if account == 'NONE':
        print('\t Skip scraping because of invalid twitter account input')
        continue
    else:
        tweetCriteria = got.manager.TweetCriteria().setUsername(account)\
                                           .setSince('2020-01-01')\
                                           .setUntil('2020-05-29')\
                                           .setMaxTweets(5000)
        tweets = got.manager.TweetManager.getTweets(tweetCriteria)
        tweets_detail = [[tweet.date, tweet.text,tweet.id,tweet.username,tweet.geo ] for tweet in tweets]
        tweets2020 = tweets2020.append(pd.DataFrame(tweets_detail, 
                                                    columns = ['Datetime', 'Text','TweetID','username','geo']), 
                                       ignore_index = True)
        print('\t Done scraping')
# Out:
# realDonaldTrump
# 	 Done scraping
# JoeBiden
# 	 Done scraping
# TulsiGabbard
# 	 Done scraping
# AndrewYang
# 	 Done scraping
# PeteButtigieg
# 	 Done scraping
# MikeBloomberg
# 	 Done scraping
# TomSteyer
# 	 Done scraping
# DevalPatric
# 	 Done scraping

# %%
print(len(tweets2020))
tweets2020.sample(5)
# Out:
# 56121
#                         Datetime  \
# 17320  2020-05-05 22:03:50+00:00
# 42667  2020-02-12 20:22:06+00:00
# 39304  2020-02-20 00:35:00+00:00
# 50399  2020-02-05 22:01:00+00:00
# 4140   2020-05-21 01:41:53+00:00
#
#                                                     Text              TweetID  \
# 17320  Montana’s educators are the best in the busine...  1257793150447386630
# 42667  Our military’s ability to prevail in the “Grea...  1227689355365507073
# 39304  I like this carbon pricing; with a little flex...  1230289714411950080
# 50399  My North Star as president will be rebuilding ...  1225177528890884096
# 4140   The Senate Judiciary Committee *should* be add...  1263283843567583235
#
#             username geo
# 17320  SenatorTester
# 42667   SenDuckworth
# 39304  SenWhitehouse
# 50399       JoeBiden
# 4140      ChrisCoons

# %%
print(tweets2020.shape)

# Remove duplicate tweets
tweets2020 = tweets2020.drop_duplicates('TweetID', keep = 'first')

print(tweets2020.shape)
# Out:
# (56121, 5)
# (56121, 5)

# %%
tweets2020.to_csv('training2020.csv', index = False)

# %%
tweets2020['Twitter Account.2'] = tweets2020['username']
tweets2020 = tweets2020.merge(data[['Twitter Account.2','Party.2', 'State.2']], how = 'left', on = 'Twitter Account.2')
tweets2020 = tweets2020.rename( columns = {'Party.2': 'Party', 'State.2':'State'})
tweets2020 = tweets2020.drop(columns = 'Twitter Account.2')
tweets2020.head()
# Out:
#                     Datetime  \
# 0  2020-05-25 15:28:49+00:00
# 1  2020-05-25 14:21:27+00:00
# 2  2020-05-25 12:24:33+00:00
# 3  2020-05-24 17:33:07+00:00
# 4  2020-05-22 22:09:24+00:00
#
#                                                 Text              TweetID  \
# 0                                                     1264941500208754688
# 1                                                     1264924547700178944
# 2  “On this Memorial Day we honor all of those wh...  1264895127677534210
# 3  Sen. Klobuchar joined @SenBrianSchatz to intro...  1264610392292147200
# 4  “At a time when many farmers and rural communi...  1263955146771496960
#
#           username geo Party State
# 0  SenAmyKlobuchar         D    MN
# 1  SenAmyKlobuchar         D    MN
# 2  SenAmyKlobuchar         D    MN
# 3  SenAmyKlobuchar         D    MN
# 4  SenAmyKlobuchar         D    MN

# %%
tweets2020 = tweets2020.drop(columns = ['Party', 'State'])

# %%
np.sum(tweets2020['Text'].isna())
# Out:
# 0

# %%
np.sum(tweets2020['username'].isna())
# Out:
# 0

# %%
np.sum(tweets2020['Party'].isna())
# Out:
# 0

# %%
np.sum(tweets2020['State'].isna())
# Out:
# 8840

# %%
tweets2020.to_csv('train2020.csv', index = False)

# %% [markdown]
# # IGNORE BELOW CODE

# %%
(datetime.strptime(electionday2012, '%Y-%m-%d')-timedelta(days = 128)).strftime('%Y-%m-%d')
# Out:
# '2012-07-01'

# %%
datetime.strptime(electionday2012, '%Y-%m-%d').strftime('%Y-%m-%d')
# Out:
# '2012-11-06'

# %%
# 2012 Election year
electionday2012 = '2012-11-06'
tweets2012 = pd.DataFrame(columns = ['Datetime', 'Text','TweetID','username','geo'])

for i in range(0, 129):
    date = (datetime.strptime(electionday2012, '%Y-%m-%d')-timedelta(days = i)).strftime('%Y-%m-%d')
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch('election')\
                                               .setSince('2012-07-01')\
                                               .setUntil(date)\
                                               .setMaxTweets(50)
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    tweets_detail = [[tweet.date, tweet.text,tweet.id,tweet.username,tweet.geo ] for tweet in tweets]
    tweets2012 = tweets2012.append(pd.DataFrame(tweets_detail, 
                                                columns = ['Datetime', 'Text','TweetID','username','geo']), 
                                   ignore_index = True)
    print(i, date, '-done')
# Out:
# 0 2012-11-06 -done
# 1 2012-11-05 -done
# 2 2012-11-04 -done
# 3 2012-11-03 -done
# 4 2012-11-02 -done
# 5 2012-11-01 -done
# 6 2012-10-31 -done
# 7 2012-10-30 -done
# 8 2012-10-29 -done
# 9 2012-10-28 -done
# 10 2012-10-27 -done
# 11 2012-10-26 -done
# 12 2012-10-25 -done
# 13 2012-10-24 -done
# 14 2012-10-23 -done
# 15 2012-10-22 -done
# 16 2012-10-21 -done
# 17 2012-10-20 -done
# 18 2012-10-19 -done
# 19 2012-10-18 -done
# 20 2012-10-17 -done
# 21 2012-10-16 -done
# 22 2012-10-15 -done
# 23 2012-10-14 -done
# 24 2012-10-13 -done
# 25 2012-10-12 -done
# 26 2012-10-11 -done
# 27 2012-10-10 -done
# 28 2012-10-09 -done
# 29 2012-10-08 -done
# 30 2012-10-07 -done
# 31 2012-10-06 -done
# 32 2012-10-05 -done
# 33 2012-10-04 -done
# 34 2012-10-03 -done
# 35 2012-10-02 -done
# 36 2012-10-01 -done
# 37 2012-09-30 -done
# 38 2012-09-29 -done
# 39 2012-09-28 -done
# 40 2012-09-27 -done
# 41 2012-09-26 -done
# 42 2012-09-25 -done
# 43 2012-09-24 -done
# 44 2012-09-23 -done
# ...

# %%
tweets2012.head(5)
# Out:
#                     Datetime  \
# 0  2012-11-05 23:59:59+00:00
# 1  2012-11-05 23:59:59+00:00
# 2  2012-11-05 23:59:59+00:00
# 3  2012-11-05 23:59:59+00:00
# 4  2012-11-05 23:59:59+00:00
#
#                                                 Text             TweetID  \
# 0  Tomorrow is the big day. Last day of election ...  265604406962188288
# 1          Election day tomorrow!... #iwantthedayoff  265604406337212416
# 2  "@F1abraham: @F1abraham ELECTION DAY 6TH:) @RO...  265604406056198146
# 3  Election Security Risks, Potential Voting Fail...  265604404525285376
# 4  ELECTION DAY: We don't get off of school, ther...  265604403376046080
#
#          username geo
# 0     sonnysizzak
# 1   Chloe_White10
# 2       MayoAmber
# 3  CyberEncrypted
# 4     icarleeeeee

# %%
tweets2012
# Out:
#                        Datetime  \
# 0     2012-11-05 23:59:59+00:00
# 1     2012-11-05 23:59:59+00:00
# 2     2012-11-05 23:59:59+00:00
# 3     2012-11-05 23:59:59+00:00
# 4     2012-11-05 23:59:59+00:00
# ...                         ...
# 6395  2012-07-01 23:55:13+00:00
# 6396  2012-07-01 23:55:13+00:00
# 6397  2012-07-01 23:55:13+00:00
# 6398  2012-07-01 23:55:12+00:00
# 6399  2012-07-01 23:55:12+00:00
#
#                                                    Text             TweetID  \
# 0     Tomorrow is the big day. Last day of election ...  265604406962188288
# 1             Election day tomorrow!... #iwantthedayoff  265604406337212416
# 2     "@F1abraham: @F1abraham ELECTION DAY 6TH:) @RO...  265604406056198146
# 3     Election Security Risks, Potential Voting Fail...  265604404525285376
# 4     ELECTION DAY: We don't get off of school, ther...  265604403376046080
# ...                                                 ...                 ...
# ...

# %%
tweets2012.to_csv('testing2012.csv', index = False)

# %%
# 2016 Election year

electionday2016 = '2016-11-08'
tweets2016 = pd.DataFrame(columns = ['Datetime', 'Text','TweetID','username','geo'])

for i in range(0, 131):
    date = (datetime.strptime(electionday2016, '%Y-%m-%d')-timedelta(days = i)).strftime('%Y-%m-%d')
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch('election')\
                                               .setSince('2016-07-01')\
                                               .setUntil(date)\
                                               .setMaxTweets(50)
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    tweets_detail = [[tweet.date, tweet.text,tweet.id,tweet.username,tweet.geo ] for tweet in tweets]
    tweets2016 = tweets2016.append(pd.DataFrame(tweets_detail, 
                                                columns = ['Datetime', 'Text','TweetID','username','geo']), 
                                   ignore_index = True)
    print(i, date, '-done')
# Out:
# 0 2016-11-08 -done
# 1 2016-11-07 -done
# 2 2016-11-06 -done
# 3 2016-11-05 -done
# 4 2016-11-04 -done
# 5 2016-11-03 -done
# 6 2016-11-02 -done
# 7 2016-11-01 -done
# 8 2016-10-31 -done
# 9 2016-10-30 -done
# 10 2016-10-29 -done
# 11 2016-10-28 -done
# 12 2016-10-27 -done
# 13 2016-10-26 -done
# 14 2016-10-25 -done
# 15 2016-10-24 -done
# 16 2016-10-23 -done
# 17 2016-10-22 -done
# 18 2016-10-21 -done
# 19 2016-10-20 -done
# 20 2016-10-19 -done
# 21 2016-10-18 -done
# 22 2016-10-17 -done
# 23 2016-10-16 -done
# 24 2016-10-15 -done
# 25 2016-10-14 -done
# 26 2016-10-13 -done
# 27 2016-10-12 -done
# 28 2016-10-11 -done
# 29 2016-10-10 -done
# 30 2016-10-09 -done
# 31 2016-10-08 -done
# 32 2016-10-07 -done
# 33 2016-10-06 -done
# 34 2016-10-05 -done
# 35 2016-10-04 -done
# 36 2016-10-03 -done
# 37 2016-10-02 -done
# 38 2016-10-01 -done
# 39 2016-09-30 -done
# 40 2016-09-29 -done
# 41 2016-09-28 -done
# 42 2016-09-27 -done
# 43 2016-09-26 -done
# 44 2016-09-25 -done
# ...

# %%
tweets2016.head(5)
# Out:
#                     Datetime  \
# 0  2016-11-07 23:59:59+00:00
# 1  2016-11-07 23:59:59+00:00
# 2  2016-11-07 23:59:59+00:00
# 3  2016-11-07 23:59:59+00:00
# 4  2016-11-07 23:59:59+00:00
#
#                                                 Text             TweetID  \
# 0  Tomorrow is election day and I'm honestly scar...  795777853510078464
# 1  Snapchat Lens Makes People Look Like Hillary C...  795777851626655744
# 2  Want to win the election? Say you'll get rid o...  795777851580678144
# 3  Happiness is: Waiting to see @realDonaldTrump ...  795777851517767680
# 4  Oh, hey, cool, my first actual election anxiet...  795777851295432704
#
#       username geo
# 0     Sosaj_69
# 1  NevadaMedia
# 2     KingRoz4
# 3  RobinBiundo
# 4  SusanArendt

# %%
tweets2016.shape
# Out:
# (6500, 5)

# %%
tweets2016.to_csv('testing2016.csv', index = False)
